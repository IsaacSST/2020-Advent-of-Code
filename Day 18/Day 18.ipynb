# %%
f = open('input.txt','r')

# %%
problems = f.read().split('\n')

# %%
problems = problems[:-1]

# %%
def evaluate(string):
    ans = 1
    op = '*'
    i = 0
    while i < len(string):
        if string[i] == '(':
            evaltup = evaluate(string[i+1:])
            if op == '*':
                ans = ans*evaltup[0]
            else:
                ans = ans+evaltup[0]
                
            i += evaltup[1]
                
        elif string[i] == ')':
            break
        elif string[i] == '*':
            op = '*'
            i += 1
        elif string[i] == '+':
            op = '+'
            i += 1
        elif string[i].isnumeric():
            if op == '*':
                ans = ans*int(string[i])
            else:
                ans = ans+int(string[i])
            i += 1
        else:
            i += 1
                
        
    return (ans,i+2)

# %%
answers = list(map(lambda x:evaluate(x)[0],problems))

# %%
answers
# Out:
# [3444,
#  4291838,
#  48396,
#  1045,
#  90135,
#  216,
#  132000,
#  18522,
#  11495875104,
#  11390,
#  4396,
#  936113640,
#  2400,
#  424,
#  396955,
#  293,
#  115564938,
#  3248700,
#  60348,
#  9607500,
#  579478,
#  52122,
#  5204,
#  171,
#  150834200,
#  786628,
#  1090669,
#  1404,
#  1107571818,
#  3785472,
#  57,
#  1974,
#  3990,
#  82494,
#  105840,
#  522,
#  52123508,
#  984,
#  22580,
#  320,
#  193752,
#  16563568,
#  63567585,
#  264924,
#  80,
#  1143570,
#  910,
#  263340,
#  1151136,
#  1692676272,
#  1260,
#  573303,
#  146520,
#  28810,
#  437058,
#  7864,
#  864,
#  3025797125,
#  64,
#  26084,
#  20275336,
#  1728,
#  590980,
#  1440,
#  518681482,
#  185536,
#  288,
#  20765,
#  1267,
#  276,
#  1590,
#  64983,
#  2577792600,
#  1389,
#  11715287094,
#  43992,
#  11623564800,
#  6363,
#  1512,
#  2899,
#  35,
#  4891,
#  1040,
#  1075294,
#  7632,
#  91,
#  472,
#  51,
#  135,
#  143811,
#  81653,
#  644436,
#  22800960,
#  19520812080,
#  540,
#  536487,
# ...

# %%
sum(answers)
# Out:
# 800602729153

# %% [markdown]
# ## Part 2

# %%
def evaluate2(string):
    
    i = 0
    strcopy = string
    while i < len(string):
        if string[i] == '(':
            evaltup = evaluate2(string[i+1:])
            print(string)
            strcopy = strcopy.replace(string[i:i+evaltup[1]],str(evaltup[0]))
            print(string)
               
            i += evaltup[1]
                
        elif string[i] == ')':
            break
            
        else:
            i += 1
         
    j = 0
    op = '*'
    prevop = '*'
    strcopy = strcopy[:i]
    #print(strcopy)
    strcopy2 = strcopy
    start = 0
    while j < len(strcopy):
        if strcopy[j] == '*':
            prevop = op
            op = '*'
            j += 1
        elif strcopy[j] == '+':
            if start == 0:
                start = j-2
            prevop = op
            op = '+'
            j += 1
        elif strcopy[j].isnumeric():
            if op == '*':
                if prevop == '+':
                    strcopy2 = strcopy2.replace(strcopy[start:j],str(evaluate2(strcopy[start:j])[0]))
                    
                    start = j + 1
            j += 1
        else:
            j += 1
            
    ans = 1
    op = '*'
    
    j = 0
    
    while j < len(strcopy2):
        if strcopy2[j] == '*':
            op = '*'
            j += 1
        elif strcopy2[j] == '+':
            op = '+'
            j += 1
        elif strcopy2[j].isnumeric():
            if op == '*':
                ans = ans*int(strcopy2[j])
            else:
                ans = ans+int(strcopy2[j])
            
            j += 1
        else:
            j += 1
                
        
    return (ans,i+2)

# %%
answers2 = list(map(lambda x:evaluate2(x)[0],problems))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-57e442011611> in <module>
# ----> 1 answers2 = list(map(lambda x:evaluate2(x)[0],problems))
#
# <ipython-input-7-57e442011611> in <lambda>(x)
# ----> 1 answers2 = list(map(lambda x:evaluate2(x)[0],problems))
#
# <ipython-input-6-3974ac0cdf31> in evaluate2(string)
#      10             i += evaltup[1]
#      11
# ---> 12         elif string[i] == ')':
#      13             break
#      14
#
# KeyboardInterrupt:

# %%
problems[0]
# Out:
# '5 + (6 + 3 + (4 + 7 * 3 + 6 + 4 + 2) * 9) * 7 + 7'

# %%
evaluate2(problems[0])
# Out:
# 6 + 3 + (4 + 7 * 3 + 6 + 4 + 2) * 9) * 7 + 7
# 6 + 3 + (4 + 7 * 3 + 6 + 4 + 2) * 9) * 7 + 7
# 5 + (6 + 3 + (4 + 7 * 3 + 6 + 4 + 2) * 9) * 7 + 7
# 5 + (6 + 3 + (4 + 7 * 3 + 6 + 4 + 2) * 9) * 7 + 7
# (63, 51)
